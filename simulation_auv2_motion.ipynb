# %%
import numpy as np
import matplotlib.pyplot as plt
import physics

test = np.array([1,0,1,1])
t,x,y,theta,v,omega,a = physics.simulate_auv2_motion(test, np.pi/4, 0.457/2, 0.338/2)
physics.plot_auv2_motion(t,x,y,theta,v,omega,a)

# %%
import numpy as np
import matplotlib.pyplot as plt
import physics

test = np.array([1,0,10,1])
t,x,y,theta,v,omega,a = physics.simulate_auv2_motion(test, np.pi/4, 0.457/2, 0.338/2)
physics.plot_auv2_motion_xy(t,x,y,theta,v,omega,a)
