# %%
import numpy as np
import matplotlib.pyplot as plt
import physics

test = np.array([1,3,1,2])
t,x,y,theta,v,omega,a = physics.simulate_auv2_motion(test, .5, 1.5, 1.8)
physics.plot_auv2_motion(t,x,y,theta,v,omega,a)
